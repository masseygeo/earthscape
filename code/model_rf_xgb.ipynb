# %%
# Random Forests or XGBoost Surficial Geologic Map Classifier...

# step 1. get data...
# iterate through training patches (and validation?)

# randomly select X points (1000-10000) in each patch

# for each point, extract predictive feature channel values 

# each point has label vector [7,] & features [36,]...save as .csv

# repeat for in-domain & cross-domain test sets...


# step 2. train classifier...
# train RF or XGB classifier on training samples...use cross validation

# test on in-domain & cross-domain test
